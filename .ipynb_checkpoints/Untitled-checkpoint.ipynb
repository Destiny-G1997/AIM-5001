# %% [markdown]
# # Week 10 Assignment Tidying and Transforming Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import re
f = open(r'C:\Users\guozi\Documents\GitHub\AIM-5001/W10.csv','w',newline='')
f.close()

# %%
s = [[497,221,212,503,1841,62,12,20,102,305,' ',
      ' ',' ',' ',' ',694,4840,383,320,201,117,415,65,129,61]]
s1 = np.array(s)
data = pd.DataFrame(s1.reshape((5,5)),
                index =[['ALASKA','ALASKA',' ','AM WEST','AM WEST'],
                        ['on time','delayed',' ','on time','delayed']],
                columns = [['Los Angeles','Phoenix','San Diego','San Francisco','Seattle']])
data
# Out:
#                 Los Angeles Phoenix San Diego San Francisco Seattle
# ALASKA  on time         497     221       212           503    1841
#         delayed          62      12        20           102     305
#
# AM WEST on time         694    4840       383           320     201
#         delayed         117     415        65           129      61

# %%
s2 = [[497,221,212,503,1841,62,12,20,102,305,694,4840,383,320,201,117,415,65,129,61]]
s3 = np.array(s2)
data1 = pd.DataFrame(s3.reshape((4,5)),
                index =[['ALASKA','ALASKA','AM WEST','AM WEST'],
                        ['on time','delayed','on time','delayed']],
                columns = [['Los Angeles','Phoenix','San Diego','San Francisco','Seattle']])
print(data1)
res = data1.stack().stack()
print(type(res))
res
# Out:
#                 Los Angeles Phoenix San Diego San Francisco Seattle
# ALASKA  on time         497     221       212           503    1841
#         delayed          62      12        20           102     305
# AM WEST on time         694    4840       383           320     201
#         delayed         117     415        65           129      61
# <class 'pandas.core.series.Series'>
# ALASKA   on time  Los Angeles    Los Angeles       497.0
#                   Phoenix        Phoenix           221.0
#                   San Diego      San Diego         212.0
#                   San Francisco  San Francisco     503.0
#                   Seattle        Seattle          1841.0
#          delayed  Los Angeles    Los Angeles        62.0
#                   Phoenix        Phoenix            12.0
#                   San Diego      San Diego          20.0
#                   San Francisco  San Francisco     102.0
#                   Seattle        Seattle           305.0
# ...

# %%
res1 = pd.DataFrame(res)
res1
# Out:
#                                                   0
# ALASKA  on time Los Angeles   Los Angeles     497.0
#                 Phoenix       Phoenix         221.0
#                 San Diego     San Diego       212.0
#                 San Francisco San Francisco   503.0
#                 Seattle       Seattle        1841.0
#         delayed Los Angeles   Los Angeles      62.0
#                 Phoenix       Phoenix          12.0
#                 San Diego     San Diego        20.0
#                 San Francisco San Francisco   102.0
#                 Seattle       Seattle         305.0
# AM WEST on time Los Angeles   Los Angeles     694.0
#                 Phoenix       Phoenix        4840.0
#                 San Diego     San Diego       383.0
#                 San Francisco San Francisco   320.0
#                 Seattle       Seattle         201.0
#         delayed Los Angeles   Los Angeles     117.0
#                 Phoenix       Phoenix         415.0
# ...

# %%
res1.to_csv(r'C:\Users\guozi\Documents\GitHub\AIM-5001/W10.csv')
c = pd.read_csv(r'C:\Users\guozi\Documents\GitHub\AIM-5001/W10.csv',
                names = ['Airlines','Status','City','','Values'])
c1 = c.loc[:,['Airlines','Status','City','Values']]
c1.to_csv(r'C:\Users\guozi\Documents\GitHub\AIM-5001/W10.csv')
c2 = pd.read_csv(r'C:\Users\guozi\Documents\GitHub\AIM-5001/W10.csv')
c21 = c2.drop(c2.index[0])
c22 = c21.drop(['Unnamed: 0'],axis=1)
c22.to_csv(r'C:\Users\guozi\Documents\GitHub\AIM-5001/W10.csv')
c3 = pd.read_csv(r'C:\Users\guozi\Documents\GitHub\AIM-5001/W10.csv')
c3
# Out:
#     Unnamed: 0 Airlines   Status           City  Values
# 0            1   ALASKA  on time    Los Angeles   497.0
# 1            2   ALASKA  on time        Phoenix   221.0
# 2            3   ALASKA  on time      San Diego   212.0
# 3            4   ALASKA  on time  San Francisco   503.0
# 4            5   ALASKA  on time        Seattle  1841.0
# 5            6   ALASKA  delayed    Los Angeles    62.0
# 6            7   ALASKA  delayed        Phoenix    12.0
# 7            8   ALASKA  delayed      San Diego    20.0
# 8            9   ALASKA  delayed  San Francisco   102.0
# 9           10   ALASKA  delayed        Seattle   305.0
# 10          11  AM WEST  on time    Los Angeles   694.0
# 11          12  AM WEST  on time        Phoenix  4840.0
# 12          13  AM WEST  on time      San Diego   383.0
# 13          14  AM WEST  on time  San Francisco   320.0
# 14          15  AM WEST  on time        Seattle   201.0
# 15          16  AM WEST  delayed    Los Angeles   117.0
# ...

# %% [markdown]
# ## Analysis

# %% [markdown]
# **Q1**:
# For each city, which airline had the best on time performance?

# %%
c31 = c3[(c3['Status'] == 'on time')&(c3['Airlines'] == 'ALASKA')][['Airlines','City','Values']]
c31
# Out:
#   Airlines           City  Values
# 0   ALASKA    Los Angeles   497.0
# 1   ALASKA        Phoenix   221.0
# 2   ALASKA      San Diego   212.0
# 3   ALASKA  San Francisco   503.0
# 4   ALASKA        Seattle  1841.0

# %%
c32 = c3[(c3['Status'] == 'on time')&(c3['Airlines'] == 'AM WEST')][['Airlines','City','Values']]
c32
# Out:
#    Airlines           City  Values
# 10  AM WEST    Los Angeles   694.0
# 11  AM WEST        Phoenix  4840.0
# 12  AM WEST      San Diego   383.0
# 13  AM WEST  San Francisco   320.0
# 14  AM WEST        Seattle   201.0

# %%
plt.plot(c31['City'],c31['Values'])
plt.title('Plot of the on time data in different cities')
plt.show()
c31.groupby('City').describe()
# Out:
#               Values
#                count    mean std     min     25%     50%     75%     max
# City
# Los Angeles      1.0   497.0 NaN   497.0   497.0   497.0   497.0   497.0
# Phoenix          1.0   221.0 NaN   221.0   221.0   221.0   221.0   221.0
# San Diego        1.0   212.0 NaN   212.0   212.0   212.0   212.0   212.0
# San Francisco    1.0   503.0 NaN   503.0   503.0   503.0   503.0   503.0
# Seattle          1.0  1841.0 NaN  1841.0  1841.0  1841.0  1841.0  1841.0

# %%
plt.plot(c32['City'],c32['Values'])
plt.title('Plot of the on time data in different cities')
plt.show()
c32.groupby('City').describe()
# Out:
#               Values
#                count    mean std     min     25%     50%     75%     max
# City
# Los Angeles      1.0   694.0 NaN   694.0   694.0   694.0   694.0   694.0
# Phoenix          1.0  4840.0 NaN  4840.0  4840.0  4840.0  4840.0  4840.0
# San Diego        1.0   383.0 NaN   383.0   383.0   383.0   383.0   383.0
# San Francisco    1.0   320.0 NaN   320.0   320.0   320.0   320.0   320.0
# Seattle          1.0   201.0 NaN   201.0   201.0   201.0   201.0   201.0

# %% [markdown]
# Answers:
# The"AM WEST" has the best on time performance in Los Angeles.
# The"AM WEST" has the best on time performance in Phoenix.
# The"AM WEST" has the best on time performance in San Diego.
# The"ALASKA" has the best on time performance in San Francisco.
# The"ALASKA" has the best on time performance in Seattle.

# %% [markdown]
# **Q2**:
# Which airline had the best overall on time performance?

# %%
c33 = c3[c3['Status'] == 'on time'][['Airlines','Values']]
c33.groupby('Airlines').describe()
# Out:
#          Values
#           count    mean          std    min    25%    50%    75%     max
# Airlines
# ALASKA      5.0   654.8   678.098223  212.0  221.0  497.0  503.0  1841.0
# AM WEST     5.0  1287.6  1994.188883  201.0  320.0  383.0  694.0  4840.0

# %% [markdown]
# **Answer**:
# According to the data, The "AM WEST" airline has the best overall on time performence.
