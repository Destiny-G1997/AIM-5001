# %% [markdown]
# # Project2 - Data analysis about US Traffic Fatalities

# %% [markdown]
# ## Introduction

# %% [markdown]
#        This data set is about US traffic fatalities from 1982--1988 with 34 columns. 29 of these columns are  numeric variables. 4 of these columns are categorical variables.
#        Traffic fatalities are from the US Department of Transportation Fatal Accident Reporting System.
#        My research question is "From 1982-1988 what's the percent of youngdirver in traffic fatalities changes in Alabam?".

# %% [markdown]
# ## Data Summary

# %% [markdown]
#       I acquired my data from "https://vincentarelbundock.github.io/Rdatasets/datasets.html".
#       The beer tax is the tax on a case of beer, which is an available measure of state alcohol taxes more generally. The drinking age variable is a factor indicating whether the legal drinking age is 18, 19, or 20. The two binary punishment variables describe the state's minimum sentencing requirements for an initial drunk driving conviction. The 'unemp' is the 'Unemployment rate'. The 'income' is 'Per capita personal income in 1987 dollars'. The 'emppop' is 'Employment/population ratio'. The 'youngdrivers' is 'Percent of drivers aged 15–24'.
#       There are 34 columns in this data set. I dropped 23 useless columns. My research will based on the 'tf'.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
filename = r'C:\Users\guozi\Documents\GitHub\AIM-5001/Fatalities.csv'
tf = pd.read_csv(filename)# reading the csv file
#Drop the useless data
tf_useless = ['emppop','income', 'beertax','baptist', 'mormon', 'milestot', 'unempus',
              'emppopus', 'gsp', 'nfatal', 'sfatal', 'pop1517','nfatal1517','pop1820',
              'nfatal1820', 'dry', 'miles','breath','service','nfatal2124','pop2124','pop','jail']
tf.drop(labels = tf_useless, axis = 1,inplace = True)

tf.head()
# Out:
#    Unnamed: 0 state  year  spirits  unemp  drinkage  youngdrivers  fatal  \
# 0           1    al  1982     1.37   14.4     19.00      0.211572    839
# 1           2    al  1983     1.36   13.7     19.00      0.210768    930
# 2           3    al  1984     1.32   11.1     19.00      0.211484    932
# 3           4    al  1985     1.28    8.9     19.67      0.211140    882
# 4           5    al  1986     1.23    9.8     21.00      0.213400   1081
#
#    fatal1517  fatal1820  fatal2124      afatal
# 0         53         99        120  309.437988
# 1         71        108        124  341.834015
# 2         49        103        118  304.872009
# 3         66        100        114  276.742004
# 4         82        120        119  360.716003

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# The state data is the state code of different states in US. The year column is 1982-1988.

# %% [markdown]
# The **unemp** column is the Unemployment rate in different states from 1982-1988. I choose Alabam as a example to do the EDA.

# %%
data = tf[['unemp','year']][(tf['state']) == 'al']
plt.plot(data['year'],data['unemp'])
plt.title('Plot of Unemployment rate in Alabam from 1982-1988')
plt.xlabel('year')
plt.show()
sns.lineplot(x = data['year'], y = data['unemp'])
data['unemp'].describe()
# Out:
# count     7.000000
# mean     10.414286
# std       2.798469
# min       7.200000
# 25%       8.350000
# 50%       9.800000
# 75%      12.400000
# max      14.400000
# Name: unemp, dtype: float64

# %% [markdown]
# **Conclusion:** The above plot, lineplot and descriptive statistics show that the Unemployment rate in Alabam with a mean of 10.41, a max of 14.4, and a min of 7.2. That tell us that the unemployment rate is on a declining curve from 1982-1988 in Alabam.

# %% [markdown]
# The **spirits** data is about spirits consumption from 1982-1988 in US.

# %%
data1 = tf[['spirits']]# get the data of spirits consumption from 1982-1988 in US
plt.plot(data1)
plt.title('Plot of spirits consumption')
plt.xlabel(' ')
plt.show()# show the data in Matplotlib.plot
data.describe()
# Out:
#           spirits
# count  336.000000
# mean     1.753690
# std      0.683575
# min      0.790000
# 25%      1.300000
# 50%      1.670000
# 75%      2.012500
# max      4.900000

# %% [markdown]
# **Conclusion:** The above plot and descriptive statistics show that the spirits consumption from 1982-1988 in different states with a minimum of 0.79, and a max of 4.9. That tells us the there should be outliers. Because, the max is 4.9, the 3rd quartile is 2.01. So every data over 2.01 could be an outlier. And we can know that the spirits consumptions are very different in different states.

# %%
sns.lineplot(data1 = tf[['spirits']])# use seaborn to show the data in lineplot

# %% [markdown]
# **Conclusion:** The above lineplot and descriptive statistics show that the spirits consumption from 1982-1988 in different states with a minimum of 0.79, and a max of 4.9. That tells us the there should be outliers. Because, the max is 4.9, the 3rd quartile is 2.01. So every data over 2.01 could be a outlier.

# %% [markdown]
# The **Drinkage** is the minimum legal drinking age from 1982-1988 in US.

# %%
data2 = tf[['drinkage']]#get the data of the minimum legal drinking age from 1982-1988 in US
plt.plot(data2)
plt.title('Plot of the minimum legal drinking age')
plt.xlabel(' ')
plt.show()# show the data in Matplotlib.plot
data2.describe()
sns.lineplot(data = tf[['drinkage']])# use the seaborn to show the data in lineplot

# %% [markdown]
# **Conclusion:** The above matplotlib plot, seaborn lineplot and descriptive statistics show that the minimum legal drinking age from 1982-1988 in different states with a mean of 20.45, a minimum of 18, and max of 21. And from the plot we can know that some states changed their the minimum legal drinking age from 1982-1988.
#
# The **fatal** column means number of vehicle fatalities in Alabam from 1982-1988.

# %%
data3 = tf[['fatal','year']][(tf['state'] == 'al')] # get the data of number of vehicle fatalities in Alabam from 1982-1988.
plt.plot(data3['year'],data3['fatal'])
plt.title('Plot of number of vehicle fatalities in different states from 1982-1988')
plt.xlabel(' ')
plt.show()# show the data of number of vehicle fatalities in Alabam from 1982-1988 by year to year
sns.lineplot(x = data3['year'], y = data3['fatal']) # use the seaborn to show the data
data3['fatal'].describe()
# Out:
# count       7.000000
# mean      971.000000
# std       102.202414
# min       839.000000
# 25%       906.000000
# 50%       932.000000
# 75%      1052.000000
# max      1110.000000
# Name: fatal, dtype: float64

# %% [markdown]
# **Conclusion:** The above plot and seaborn lineplot show us that the number of vehicle fatalities in Alabam from 1982-1988 with a mean of 971, a min of 839, and a max of 1110. And we can know the tendency of this data is on the rise in these 7 years.

# %% [markdown]
# The **fatal1517** column is number of vehicle fatalities, 15–17 year olds in different states from 1982-1988. I choose the Alabam as a example to do the EDA.

# %%
data4 = tf[['year','fatal1517']][(tf['state'] == 'al')]
plt.plot(data4['year'],data4['fatal1517'])
plt.title('Plot of number of vehicle fatalities, 15–17 year olds')
plt.xlabel('year')
plt.ylabel('number of vehicle fatalities, 15–17 year olds')
plt.show()
sns.lineplot(x = data4['year'], y = data4['fatal1517'])
data4['fatal1517'].describe()
# Out:
# count     7.000000
# mean     68.714286
# std      15.660080
# min      49.000000
# 25%      59.500000
# 50%      66.000000
# 75%      76.500000
# max      94.000000
# Name: fatal1517, dtype: float64

# %% [markdown]
# **Conclusion:** The above plots and descriptive statistics show the number of vehicle fatalities, 15–17 year olds in Alabam from 1982-1988 with a mean of 68, a max of 94, and a min of 49. From the plots, we know that from 1982 to 1988 the vehicle fatalities in 15-17-year-olds is increased in 1983, 1985, 1986, 1987, and decreased in 1984 and 1988. In total it increased.

# %% [markdown]
# The **fatal1820** column is number of vehicle fatalities, 18-20 year olds in different states from 1982-1988. I choose the Alabam as a example to do the EDA.

# %%
data5 = tf[['year','fatal1820']][(tf['state'] == 'al')]
plt.plot(data5['year'],data5['fatal1820'])
plt.title('Plot of number of vehicle fatalities, 18–20 year olds')
plt.xlabel('year')
plt.ylabel('number of vehicle fatalities, 18–20 year olds')
plt.show()
sns.lineplot(x = data5['year'], y = data5['fatal1820'])
data5['fatal1820'].describe()
# Out:
# count      7.000000
# mean     108.857143
# std       10.636863
# min       99.000000
# 25%      101.500000
# 50%      105.000000
# 75%      114.000000
# max      127.000000
# Name: fatal1820, dtype: float64

# %% [markdown]
# **Conclusion:** The above plots and descriptive statistics show the number of vehicle fatalities, 18–20 year olds in Alabam from 1982-1988 with a mean of 108, a max of 127, and a min of 99. From the plots, we know that from 1982 to 1988 the vehicle fatalities in 18-20-year-olds' mean is bigger than 15-17-year-old's mean. So the rate of traffic fatalities is more in this range of age.

# %% [markdown]
# The **fatal2124** column is number of vehicle fatalities, 18-20 year olds in different states from 1982-1988. I choose the Alabam as a example to do the EDA.

# %%
data6 = tf[['year','fatal2124']][(tf['state'] == 'al')]
plt.plot(data6['year'],data6['fatal2124'])
plt.title('Plot of number of vehicle fatalities, 21–24 year olds')
plt.xlabel('year')
plt.ylabel('number of vehicle fatalities, 21–24 year olds')
plt.show()
sns.lineplot(x = data6['year'], y = data6['fatal2124'])
data6['fatal2124'].describe()
# Out:
# count      7.000000
# mean     122.285714
# std        7.674944
# min      114.000000
# 25%      118.500000
# 50%      120.000000
# 75%      123.500000
# max      138.000000
# Name: fatal2124, dtype: float64

# %% [markdown]
# **Conclusion:** The above plots and descriptive statistics show the number of vehicle fatalities, 21–24 year olds in Alabam from 1982-1988 with a mean of 122, a max of 138, and a min of 114. From the plots, we know that from 1982 to 1988 the number of vehicle fatalities of young drivers(15-24) are increasing with the age growing.

# %% [markdown]
# The **afatal** column is number of alcohol-involved vehicle fatalities in different states from 1982-1988. I choose the Alabam as a example to do the EDA.

# %%
data7 = tf[['year','afatal']][(tf['state'] == 'al')]
plt.plot(data7['year'],data7['afatal'])
plt.title('Plot of number of alcohol-involved vehicle fatalities')
plt.xlabel('year')
plt.ylabel('number of alcohol-involved vehicle fatalities')
plt.show()
sns.lineplot(x = data7['year'], y = data7['afatal'])
data7['afatal'].describe()
# Out:
# count      7.000000
# mean     322.906429
# std       34.403441
# min      276.742004
# 25%      301.597000
# 50%      309.437988
# 75%      351.275009
# max      368.420990
# Name: afatal, dtype: float64

# %% [markdown]
# **Conclusion:** The above plots and descriptive statistics show the number of alcohol-involved vehicle fatalities in Alabam from 1982-1988 with a mean of 322.9, a max of 368, and a min of 276. From the plots, we know that in 1982-1988 the number of alcohol-involved vehicle fatalities in Alabam decreased in total. And the state did a great job to decrease the number in 1985.

# %% [markdown]
# ## Inference

# %% [markdown]
# **Research question:** From 1982-1988 what's the percent of youngdirver in traffic fatalities changes in Alabam?

# %% [markdown]
# - To get a sub set data use for the research question.
# - The state column is the states of the US. The youngdrivers means percent of drivers aged 15–24.

# %%
tf1 = tf[['state','year','youngdrivers']]#get the data of the percent of youngdirver in traffic fatalities changes in Alabam
#from 1982-1988
yr = tf1[tf1['state']=='al']
print(type(yr))
yr
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   state  year  youngdrivers
# 0    al  1982      0.211572
# 1    al  1983      0.210768
# 2    al  1984      0.211484
# 3    al  1985      0.211140
# 4    al  1986      0.213400
# 5    al  1987      0.215527
# 6    al  1988      0.218328

# %%
plt.plot(yr['year'],yr['youngdrivers'])
plt.title('youngdriver changes from 1982-1988 in Alabam')
plt.xlabel(' ')
plt.show()#show the percent of youngdirver in traffic fatalities changes in Alabam year by year
sns.lineplot(x = yr['year'], y = yr['youngdrivers'])#use the seaborn linplot to show the data
yr['youngdrivers'].describe()
# Out:
# count    7.000000
# mean     0.213174
# std      0.002814
# min      0.210768
# 25%      0.211312
# 50%      0.211572
# 75%      0.214464
# max      0.218328
# Name: youngdrivers, dtype: float64

# %% [markdown]
# **Result:** The above matplotlib plot, seaborn lineplot, and descriptive statistics show that 'youngdirver' changes in Alabam from 1982-1988 with a mean of 0.213, a minimum of 0.210, and a max of 0.218. And from the plot, we can know that the percent of young drivers in traffic fatalities didn't change too much from 1982-1988. But starting from 1985 the data is on the rise.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From this research I know that:
# - The percent of youngdirver in traffic fatalities didn't change too much from 1982-1988
# - The changing tendency of the percent of youngdirver in traffic fatalities in Alabam was on the rise from 1982-1988.
# - Some states changed their minimum legal drinking age from 1982-1988.

# %% [markdown]
# ## References

# %% [markdown]
# The data info are from https://vincentarelbundock.github.io/Rdatasets/doc/AER/Fatalities.html
